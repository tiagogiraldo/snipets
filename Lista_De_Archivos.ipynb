# %%
import pandas as pd
import numpy as np
import os
from os import listdir
from os.path import isfile, join

# %%
mypath1 = r'C:\Users\PC1\Documents\PHD\01_RevBiblio'
mypath2 = r'C:\Users\PC1\Documents\PHD\02_RevBiblio_arXiv'

# %%
revbiblio1 = [f for f in listdir(mypath1) if isfile(join(mypath1, f))]
revbiblio2 = [f for f in listdir(mypath2) if isfile(join(mypath2, f))]

# %%
revbiblio1
# Out:
# ['20010604 Learning to Trade via Direct Reinforcement 00935097.pdf',
#  '20051020 Robust Artificial Neural Networks for Pricing of European Options Andreou2006_Article_RobustArtificialNeuralNetworks.pdf',
#  '20070327 Strategic asset allocation and market timing - a reinforcement learning approach Hens-Wöhrmann2007_Article_StrategicAssetAllocationAndMar.pdf',
#  '20071101 A Multiagent Approach to Q-Learning for Daily Stock Trading 04342801.pdf',
#  '20090201 Computational Intelligence for Evolving Trading Rules 04769003.pdf',
#  '20090512 Neural correlates of risk prediction error during reinforcement learning in humans 1-s2.0-S1053811909004819-main.pdf',
#  '20090621 PredictinginvestmentbehaviorAnaugmentedreinforcement learning model 1-s2.0-S0925231209001817-main.pdf',
#  '20100101 Stock trading with cycles A financial application of ANFIS and reinforcement learning1-s2.0-S095741741000905X-main.pdf',
# ...

# %%
revbiblio2
# Out:
# ['20140524 Intelligent Trading of Seasonal Effects - A Decision Support Algorithm based on Reinforcement Learning eilers2014.pdf',
#  '20190603 Analysis of multi-level capital market linkage driven by artificial intelligence and deep learning methods Jing2019_Article_AnalysisOfMulti-levelCapitalMa.pdf',
#  '20190611 A deep learning approach for financial market prediction utilization of Google trends and keywords Fan2019_Article_ADeepLearningApproachForFinanc.pdf',
#  '20190612 Deep Smoothing of the Implied Volatility Surface 1906.05065v1.pdf',
#  'arXiv 20121201 A Machine Learning Model for Stock Market Prediction 1402.7351.pdf',
#  'arXiv 20130121 Evaluation of a Supervised Learning Approach for Stock Market Operations 1301.4944v1.pdf',
#  'arXiv 20140604 Integration of a Predictive, Continuous Time Neural Network into Securities Market Trading Operations 1406.0968.pdf',
# ...

# %%
revbiblio=[]
revbiblio = revbiblio1 
for i in revbiblio2:
    revbiblio.append(i)

# %%
revbiblio
# Out:
# ['20010604 Learning to Trade via Direct Reinforcement 00935097.pdf',
#  '20051020 Robust Artificial Neural Networks for Pricing of European Options Andreou2006_Article_RobustArtificialNeuralNetworks.pdf',
#  '20070327 Strategic asset allocation and market timing - a reinforcement learning approach Hens-Wöhrmann2007_Article_StrategicAssetAllocationAndMar.pdf',
#  '20071101 A Multiagent Approach to Q-Learning for Daily Stock Trading 04342801.pdf',
#  '20090201 Computational Intelligence for Evolving Trading Rules 04769003.pdf',
#  '20090512 Neural correlates of risk prediction error during reinforcement learning in humans 1-s2.0-S1053811909004819-main.pdf',
#  '20090621 PredictinginvestmentbehaviorAnaugmentedreinforcement learning model 1-s2.0-S0925231209001817-main.pdf',
#  '20100101 Stock trading with cycles A financial application of ANFIS and reinforcement learning1-s2.0-S095741741000905X-main.pdf',
# ...

# %%
df = pd.DataFrame({'lista':revbiblio})

# %%
df
# Out:
#                                                  lista
# 0    20010604 Learning to Trade via Direct Reinforc...
# 1    20051020 Robust Artificial Neural Networks for...
# 2    20070327 Strategic asset allocation and market...
# 3    20071101 A Multiagent Approach to Q-Learning f...
# 4    20090201 Computational Intelligence for Evolvi...
# 5    20090512 Neural correlates of risk prediction ...
# 6    20090621 PredictinginvestmentbehaviorAnaugment...
# 7    20100101 Stock trading with cycles A financial...
# 8    20100206 Heterogeneous trading strategies with...
# 9    20100421 Learning bydoingvs.learningfromothers...
# 10   20101105 Detection of Information Flow in Majo...
# 11   20110301 An Investigation into the Use of Inte...
# 12   20110813 Nonlinearity in Forecasting of High-F...
# 13   20110910 Regime-switching recurrent reinforcem...
# 14   20120101 Testing different Reinforcement Learn...
# 15   20120101 Testing different Reinforcement Learn...
# ...

# %%
df.to_csv('lista.csv', index=False)
